# %%
import pandas as pd
import numpy as np
df=pd.read_csv(r"C:\Users\LENOVO\Downloads\iyPaw9UGRD-F_oU318b6Cg_f07cadf326314912bcac2fea48e87ff1_2017_Yellow_Taxi_Trip_Data.csv")
df.head()
# Out:
#    Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0    24870114         2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 1    35634249         1   04/11/2017 2:53:28 PM   04/11/2017 3:19:58 PM
# 2   106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 3    38942136         2   05/07/2017 1:17:59 PM   05/07/2017 1:48:14 PM
# 4    30841670         2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# 1                1           1.80           1                  N
# 2                1           1.00           1                  N
# 3                1           3.70           1                  N
# 4                1           4.37           1                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# ...

# %%
df.shape
# Out:
# (22699, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             22699 non-null  int64
#  1   VendorID               22699 non-null  int64
#  2   tpep_pickup_datetime   22699 non-null  object
#  3   tpep_dropoff_datetime  22699 non-null  object
#  4   passenger_count        22699 non-null  int64
#  5   trip_distance          22699 non-null  float64
#  6   RatecodeID             22699 non-null  int64
#  7   store_and_fwd_flag     22699 non-null  object
#  8   PULocationID           22699 non-null  int64
#  9   DOLocationID           22699 non-null  int64
#  10  payment_type           22699 non-null  int64
#  11  fare_amount            22699 non-null  float64
#  12  extra                  22699 non-null  float64
#  13  mta_tax                22699 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#          Unnamed: 0      VendorID  passenger_count  trip_distance  \
# count  2.269900e+04  22699.000000     22699.000000   22699.000000
# mean   5.675849e+07      1.556236         1.642319       2.913313
# std    3.274493e+07      0.496838         1.285231       3.653171
# min    1.212700e+04      1.000000         0.000000       0.000000
# 25%    2.852056e+07      1.000000         1.000000       0.990000
# 50%    5.673150e+07      2.000000         1.000000       1.610000
# 75%    8.537452e+07      2.000000         2.000000       3.060000
# max    1.134863e+08      2.000000         6.000000      33.960000
#
#          RatecodeID  PULocationID  DOLocationID  payment_type   fare_amount  \
# count  22699.000000  22699.000000  22699.000000  22699.000000  22699.000000
# mean       1.043394    162.412353    161.527997      1.336887     13.026629
# std        0.708391     66.633373     70.139691      0.496211     13.243791
# ...

# %%
df['tpep_dropoff_datetime']=pd.to_datetime(df['tpep_dropoff_datetime'])

# %%
df['tpep_pickup_datetime']=pd.to_datetime(df['tpep_pickup_datetime'])

# %%
df.dtypes
# Out:
# Unnamed: 0                        int64
# VendorID                          int64
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                   int64
# trip_distance                   float64
# RatecodeID                        int64
# store_and_fwd_flag               object
# PULocationID                      int64
# DOLocationID                      int64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# dtype: object

# %%
df['trip_duration_min']=(df['tpep_dropoff_datetime']-df['tpep_pickup_datetime']).dt.total_seconds()/60

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             22699 non-null  int64
#  1   VendorID               22699 non-null  int64
#  2   tpep_pickup_datetime   22699 non-null  datetime64[ns]
#  3   tpep_dropoff_datetime  22699 non-null  datetime64[ns]
#  4   passenger_count        22699 non-null  int64
#  5   trip_distance          22699 non-null  float64
#  6   RatecodeID             22699 non-null  int64
#  7   store_and_fwd_flag     22699 non-null  object
#  8   PULocationID           22699 non-null  int64
#  9   DOLocationID           22699 non-null  int64
#  10  payment_type           22699 non-null  int64
#  11  fare_amount            22699 non-null  float64
#  12  extra                  22699 non-null  float64
#  13  mta_tax                22699 non-null  float64
# ...

# %%
df=df.rename(columns={'Unnamed: 0':'trip_ID'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   trip_ID                22699 non-null  int64
#  1   VendorID               22699 non-null  int64
#  2   tpep_pickup_datetime   22699 non-null  datetime64[ns]
#  3   tpep_dropoff_datetime  22699 non-null  datetime64[ns]
#  4   passenger_count        22699 non-null  int64
#  5   trip_distance          22699 non-null  float64
#  6   RatecodeID             22699 non-null  int64
#  7   store_and_fwd_flag     22699 non-null  object
#  8   PULocationID           22699 non-null  int64
#  9   DOLocationID           22699 non-null  int64
#  10  payment_type           22699 non-null  int64
#  11  fare_amount            22699 non-null  float64
#  12  extra                  22699 non-null  float64
#  13  mta_tax                22699 non-null  float64
# ...

# %%
df.head(10)
# Out:
#      trip_ID  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0   24870114         2  2017-03-25 08:55:43   2017-03-25 09:09:47
# 1   35634249         1  2017-04-11 14:53:28   2017-04-11 15:19:58
# 2  106203690         1  2017-12-15 07:26:56   2017-12-15 07:34:08
# 3   38942136         2  2017-05-07 13:17:59   2017-05-07 13:48:14
# 4   30841670         2  2017-04-15 23:32:20   2017-04-15 23:49:03
# 5   23345809         2  2017-03-25 20:34:11   2017-03-25 20:42:11
# 6   37660487         2  2017-05-03 19:04:09   2017-05-03 20:03:47
# 7   69059411         2  2017-08-15 17:41:06   2017-08-15 18:03:05
# 8    8433159         2  2017-02-04 16:17:07   2017-02-04 16:29:14
# 9   95294817         1  2017-11-10 15:20:29   2017-11-10 15:40:55
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# 1                1           1.80           1                  N
# ...

# %%
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df['trip_distance'])
plt.title('Trip Distance')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['trip_distance'], bins=50)
plt.title('Trip Distance histogram')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df['total_amount'])
plt.title('Total Amount')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df['total_amount'])
plt.xlim(0,50)
plt.title('Total Amount zoomed in ($0-$50)')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['total_amount'], bins=50)
plt.title('Total Amount Histogram')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['total_amount'], bins=50)
plt.xlim(0,200)
plt.title('Total Amount Histogram Zoomed in ($0-$200)')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df['tip_amount'])
plt.title('Tip Amount')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df['tip_amount'])
plt.xlim(-3,10)
plt.title('Tip Amount zoomed in ($0-$10)')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(df['tip_amount'], bins=50)
plt.title('Tip Amount Histogram')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(df['tip_amount'], bins=50)
plt.xlim(0,50)
plt.title('Tip Amount Histogram zoomed in ($0-$50)')
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.histplot(data=df, x='tip_amount', hue='VendorID', bins=50, multiple='stack')
plt.title('Tip Amount by Vendor')
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.histplot(data=df, x='tip_amount', hue='VendorID', bins=50, multiple='stack')
plt.xlim(0,30)
plt.title('Tip Amount by Vendor zoomed in ($0-$30)')
plt.show()

# %%
big_tips=df[df['tip_amount']>10]
plt.figure(figsize=(8,4))
sns.histplot(data=big_tips, x='tip_amount', hue='VendorID', bins=30, multiple='stack')
plt.title('Tips Over $10 by Vendor')
plt.show()

# %%
big_tips=df[df['tip_amount']>10]
plt.figure(figsize=(8,4))
sns.histplot(data=big_tips, x='tip_amount', hue='VendorID', bins=30, multiple='stack')
plt.xlim(10,75)
plt.title('Tips Over $10 by Vendor zoomed in ($10-$75)')
plt.show()

# %%
df['passenger_count'].value_counts().sort_index()
# Out:
# passenger_count
# 0       33
# 1    16117
# 2     3305
# 3      953
# 4      455
# 5     1143
# 6      693
# Name: count, dtype: int64

# %%
mean_tips_by_passenger=df.groupby('passenger_count')['tip_amount'].mean()
plt.figure(figsize=(8,4))
mean_tips_by_passenger.plot(kind='bar')
plt.title('Mean Tip Amount by Passenger Count')
plt.xlabel('Passenger Count')
plt.ylabel('Mean Tip ($)')
plt.show()

# %%
df['month']=df['tpep_pickup_datetime'].dt.month_name()
df['day']=df['tpep_pickup_datetime'].dt.day_name()

# %%
monthly_rides=df['month'].value_counts()
monthly_rides
# Out:
# month
# March        2049
# October      2027
# April        2019
# May          2013
# January      1997
# June         1964
# December     1863
# November     1843
# February     1769
# September    1734
# August       1724
# July         1697
# Name: count, dtype: int64

# %%
month_order=['January','February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'Novenber', 'December']
monthly_rides=monthly_rides.reindex(month_order)
monthly_rides
# Out:
# month
# January      1997.0
# February     1769.0
# March        2049.0
# April        2019.0
# May          2013.0
# June         1964.0
# July         1697.0
# August       1724.0
# September    1734.0
# October      2027.0
# Novenber        NaN
# December     1863.0
# Name: count, dtype: float64

# %%
plt.figure(figsize=(8,4))
monthly_rides.plot(kind='bar')
plt.title('Total Ride per Month')
plt.xlabel('Month')
plt.ylabel('Number of Rides')
plt.show()

# %%
day_order=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
daily_rides=df['day'].value_counts().reindex(day_order)
daily_rides
# Out:
# day
# Monday       2931
# Tuesday      3198
# Wednesday    3390
# Thursday     3402
# Friday       3413
# Saturday     3367
# Sunday       2998
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,4))
daily_rides.plot(kind='bar')
plt.title('Total Rides per Day')
plt.xlabel('Day')
plt.ylabel('Number of Rides')
plt.show()

# %%
revenue_by_day=df.groupby('day')['total_amount'].sum().reindex(day_order)
revenue_by_day
# Out:
# day
# Monday       49574.37
# Tuesday      52527.14
# Wednesday    55310.47
# Thursday     57181.91
# Friday       55818.74
# Saturday     51195.40
# Sunday       48624.06
# Name: total_amount, dtype: float64

# %%
plt.figure(figsize=(8,4))
revenue_by_day.plot(kind='bar')
plt.title('Total Revenue by Day of Week')
plt.xlabel('Day')
plt.ylabel('Total Revenue($)')
plt.show()

# %%
revenue_by_month=df.groupby('month')['total_amount'].sum().reindex(month_order)
revenue_by_month
# Out:
# month
# January      31735.25
# February     28937.89
# March        33085.89
# April        32012.54
# May          33828.58
# June         32920.52
# July         26617.64
# August       27759.56
# September    28206.38
# October      33065.83
# Novenber          NaN
# December     31261.57
# Name: total_amount, dtype: float64

# %%
plt.figure(figsize=(8,4))
revenue_by_month.plot(kind='bar')
plt.title('Total Revenue by Month')
plt.xlabel('Month')
plt.ylabel('Total Revenue($)')
plt.show()

# %%
df['DOLocationID'].nunique()
# Out:
# 216

# %%
mean_distance_by_dropoff=df.groupby('DOLocationID')['trip_distance'].mean()
mean_distance_by_dropoff
# Out:
# DOLocationID
# 1      17.027353
# 4       2.436634
# 7       3.964944
# 9       9.305000
# 10      3.750000
#          ...
# 261     4.935897
# 262     2.866897
# 263     2.501951
# 264     2.928783
# 265    11.039000
# Name: trip_distance, Length: 216, dtype: float64

# %%
mean_distance_by_dropoff= mean_distance_by_dropoff.sort_values(ascending=False)
mean_distance_by_dropoff
# Out:
# DOLocationID
# 23     24.275000
# 29     21.650000
# 210    20.500000
# 11     17.945000
# 51     17.310000
#          ...
# 137     1.818852
# 234     1.727806
# 237     1.555494
# 193     1.390556
# 207     1.200000
# Name: trip_distance, Length: 216, dtype: float64

# %%
plt.figure(figsize=(8,4))
mean_distance_by_dropoff.sort_values(ascending=True).plot(kind='bar')
plt.title('Mean Trip Distance by Drop-off Location')
plt.xlabel('Drop-off Locatuon ID')
plt.ylabel('Mean Trip Distance (miles)')
plt.xticks([])
plt.show()

# %%
df.to_csv(r'C:\Users\LENOVO\Downloads\taxi_data_cleaned.csv', index=False)

# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
df.describe(include='all')
# Out:
#              trip_ID      VendorID           tpep_pickup_datetime  \
# count   2.269900e+04  22699.000000                          22699
# unique           NaN           NaN                            NaN
# top              NaN           NaN                            NaN
# freq             NaN           NaN                            NaN
# mean    5.675849e+07      1.556236  2017-06-29 07:32:48.973126656
# min     1.212700e+04      1.000000            2017-01-01 00:08:25
# 25%     2.852056e+07      1.000000     2017-03-30 03:09:38.500000
# 50%     5.673150e+07      2.000000            2017-06-23 12:35:57
# 75%     8.537452e+07      2.000000            2017-10-02 10:34:34
# max     1.134863e+08      2.000000            2017-12-31 23:45:30
# std     3.274493e+07      0.496838                            NaN
#
#                 tpep_dropoff_datetime  passenger_count  trip_distance  \
# count                           22699     22699.000000   22699.000000
# ...

# %%
df.groupby('payment_type')['fare_amount'].mean()
# Out:
# payment_type
# 1    13.429748
# 2    12.213546
# 3    12.186116
# 4     9.913043
# Name: fare_amount, dtype: float64

# %%
credit_card=df[df['payment_type']==1]['fare_amount']
cash=df[df['payment_type']==2]['fare_amount']
stats.ttest_ind(a=credit_card, b=cash, equal_var=False)
# Out:
# TtestResult(statistic=np.float64(6.866800855655361), pvalue=np.float64(6.7973874730310106e-12), df=np.float64(16675.48547403633))
